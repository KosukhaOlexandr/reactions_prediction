# %% [markdown]
# <a href="https://colab.research.google.com/github/KosukhaOlexandr/reactions_prediction/blob/main/reactions_prediction_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

with open('/content/drive/MyDrive/reaction_prediction/clear_dataset_from_Sep_21.json') as f:
  data = pd.read_json(f,  orient = 'records')

# %%
data
# Out:
#        message_id                date  \
# 0           68765 2023-01-10 15:58:31
# 1           68764 2023-01-10 15:48:51
# 2           68762 2023-01-10 15:46:28
# 3           68761 2023-01-10 15:32:42
# 4           68760 2023-01-10 15:26:41
# ...           ...                 ...
# 10979       53699 2022-09-21 08:13:35
# 10980       53698 2022-09-21 08:03:22
# 10981       53697 2022-09-21 07:36:56
# 10982       53696 2022-09-21 06:31:43
# 10983       53695 2022-09-21 00:31:07
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       msg_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                            🥴 Донька міністра оборони РФ Сергія Шойгу Ксенія засвітилася на дороговартісному курорті в ОАЕ під час новорічних свят\n\nСвітлину опублікував російський депутат Денис Долженко. Журналісти з’ясували, що її зробили в одному з найшикарніших торгових центрів у Дубаї.\n\nА на Росії тим часом "підгорає" на тлі обговорень про мобілізацію на Росії 15 січня.💪\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 1                                                                                                                                                                                                                                                                           ⚡️НАТО та ЄС підписали декларацію про співпрацю - першу за останні п'ять років\n\nКоментуючи підписання декларації, генеральний секретар НАТО Єнс Столтенберг акцентував на важливості співпраці між альянсом і ЄС в контексті зміни обстановки в сфері безпеки після вторгнення Росії в Україну. \n\n"Зараз це важливо більше, ніж будь-коли. ... Президент Путін хотів захопити Україну за три дні і розділити нас. За обома пунктами він провалився", – сказав Столтенберг на прес-конференції.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 🥶🇷🇺У Мегіоні на Росії все стабільно: на вулиці сорокаградусний мороз, а мешканці більшості  багатоповерхівок залишились без опалення, через прорив теплотраси.\n\nВідео опублікували росЗМІ.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 3                                                                                                                                                                                                                                                                                                                                                                                                                            ⚖️😡 У Києві під суд піде викладачка гімназії, яка назвала столицю "власністю Москви"\n\nСлідство з’ясувало, що від початку війни Росії проти України киянка-інструкторка з фізичного виховання в одній зі столичних гімназій неодноразово поширювала у соцмережах дописи на підтримку і виправдання збройної агресії Росії. Нині вона під вартою.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  😱🎥 З’явилось відео наслідків російської атаки в Херсоні. Величезна вирва від російського снаряду, який розірвався просто у дворі багатоповерхівки.\n\nОдна людина поранена. Мешканці шоковані, в декого не лишилося жодного вцілілого вікна, вибуховою хвилею вибило двері.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 10979                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          🇺🇳🇺🇸 Перша леді Олена Зеленська та прем'єр-міністр Денис Шмигаль прибули до Нью-Йорка на засідання 77-ї Генасамблеї ООН, де представлятимуть Україну, - ЗМІ публікують відео. \n\nПовідомляється, що вже відбулась зустріч із генсеком ООН Антоніу Гуттерішем. \n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 10980                                                                                                                                                                                              🇺🇦🙌 Українські захисники поцілили у військову "комендатуру" в Сватовому на Луганщині та ліквідували пів сотні окупантів з технікою на Запоріжжі.\n\n"Підтверджено ураження місця зосередження особового складу у Пологівському районі, чисельністю понад 20 осіб; у Мелітопольському районі – складу боєприпасів, 5 одиниць військової техніки та понад 20 військовослужбовців; у районі населеного пункту Кам’янка – 10 одиниць військової техніки та понад 10 військовослужбовців підрозділів окупаційних військ".\n\n👉 Про це йдеться у ранковому зведенні Генштабу ЗСУ.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 10981                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            😡Росіяни обстріляли ЗАЕС: пошкоджено обладнання зв’язку одного з енергоблоків
# 10982                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            👉 ТСН.ua пропонує дізнатися головні події ночі, які ви могли проспати. https://bit.ly/3qVLtrY
# 10983  Ситуація на передовій чітко свідчить про те, що ініціатива – за Україною. Наші оборонці дуже акуратно й дуже хоробро виконують завдання, які ставить перед ними командування. Хочу сьогодні особливо відзначити 81-шу окрему десантно-штурмову бригаду – за сміливість при звільненні населених пунктів на Донеччині. А також 93-тю окрему механізовану бригаду – за героїчну оборону Бахмута і Соледара. Дякую вам! Дякую всім нашим героям!\n\nБільше підтримки для Збройних Сил України, більше підтримки для розвідки, більше підтримки для Сил спеціальних операцій, більше підтримки для СБУ, для Нацгвардії, для поліції, для прикордонників – для всіх, хто поступово відновлює нашу територіальну цілісність.\n\nСлава кожному й кожній, хто захищає державу! Слава нашому прекрасному народу!\nСлава Україні!
#
#         views  \
# 0        2011
# 1       22569
# 2       27773
# 3       49711
# 4       55128
# ...       ...
# 10979  182828
# 10980  212136
# 10981  215644
# 10982  217675
# 10983  202621
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       reactions
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'_client': None, 'emoji': '🤮', 'count': 4, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 3, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 1, 'chosen': False}]
# 1                                                                                                                                                                                                                                                                                                                                       [{'_client': None, 'emoji': '👍', 'count': 363, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 52, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 7, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 4, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 1, 'chosen': False}]
# 2                                                                                                                                                                                                        [{'_client': None, 'emoji': '👍', 'count': 473, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 59, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 37, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 25, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '🤩', 'count': 5, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 4, 'chosen': False}, {'_client': None, 'emoji': '😢', 'count': 2, 'chosen': False}]
# 3                                                                          [{'_client': None, 'emoji': '🤬', 'count': 1015, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 356, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 87, 'chosen': False}, {'_client': None, 'emoji': '🤯', 'count': 29, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 21, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 7, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 1, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 1, 'chosen': False}]
# 4             [{'_client': None, 'emoji': '🤬', 'count': 508, 'chosen': False}, {'_client': None, 'emoji': '😢', 'count': 178, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 37, 'chosen': False}, {'_client': None, 'emoji': '🤯', 'count': 16, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 5, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 3, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 1, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 1, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 1, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 1, 'chosen': False}]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 10979       [{'_client': None, 'emoji': '👍', 'count': 3107, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 576, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 67, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 42, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 22, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 15, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 8, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 7, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 7, 'chosen': False}, {'_client': None, 'emoji': '🎉', 'count': 5, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 4, 'chosen': False}]
# 10980                                                                                                                                   [{'_client': None, 'emoji': '👍', 'count': 3054, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 614, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 174, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 71, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 31, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 8, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 1, 'chosen': False}]
# 10981    [{'_client': None, 'emoji': '🤬', 'count': 3286, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 401, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 61, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 46, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 38, 'chosen': False}, {'_client': None, 'emoji': '😢', 'count': 33, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 25, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 18, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 4, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 3, 'chosen': False}]
# 10982                                                                                                                                                                                                                                                                   [{'_client': None, 'emoji': '👍', 'count': 476, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 52, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 29, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 22, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 6, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 3, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 2, 'chosen': False}]
# 10983  [{'_client': None, 'emoji': '❤', 'count': 3764, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 934, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 82, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 48, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 32, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 29, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 13, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 13, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 12, 'chosen': False}, {'_client': None, 'emoji': '😢', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 10, 'chosen': False}]
#
# [10984 rows x 5 columns]

# %% [markdown]
# we need to delete posts from the last day to prevent undervoting in data

# %%
data.drop(data[data['date'].dt.date == data['date'].iloc[0].date()].index, inplace = True)

# %%
data
# Out:
#        message_id                date  \
# 55          68680 2023-01-09 23:47:14
# 56          68679 2023-01-09 23:31:05
# 57          68678 2023-01-09 23:17:08
# 58          68676 2023-01-09 23:02:42
# 59          68675 2023-01-09 22:45:02
# ...           ...                 ...
# 10979       53699 2022-09-21 08:13:35
# 10980       53698 2022-09-21 08:03:22
# 10981       53697 2022-09-21 07:36:56
# 10982       53696 2022-09-21 06:31:43
# 10983       53695 2022-09-21 00:31:07
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       msg_text  \
# 55                                                                                                                                                                                                                                                                                                                             Міноборони висміяло фейки РФ про "знищені" M142 HIMARS та "вбитих" українських військових\n\n""Знищені", згідно з заявами російського Міноборони, HIMARS щодня спалюють склади та казарми окупантів. Сотні нібито "убитих" українських солдатів відбивають атаки рашистських смертників у Бахмуті та Соледарі. Історія знає битви, виграні за допомогою підступності. Але брехня щоразу перемагає саму себе", - зазначили у Міноборони України.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ❗️ Вибухи в Бєлгородській області\n\nГучно цього вечора відразу в декількох населених пунктах регіону РФ, повідомляють місцеві. \n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Challenger 2: що відомо про танк, який Велика Британія може надіслати ЗСУ\n\nСполучене Королівство може стати першою країною, яка відправить ЗСУ власні танки для протистояння РФ. Про основні характеристики танку Challenger 2 читайте в матеріалі ТСН.uа.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   🤬 Ракетний удар по Краматорську. Окупанти влучили у проїжджу частину та автомобіль, - Офіс президента. \n\nЗагинули двоє людей, які перебували в автівці.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       🇺🇦🇬🇧 Велика Британія у 2023 хоче досягти або перевищити минулорічний рівень надання допомоги Україні \n\nПро це повідомляє британське Міністерство оборони. Там запевняють, що непохитно підтримуватимуть Україну для захисту від РФ.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 10979                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          🇺🇳🇺🇸 Перша леді Олена Зеленська та прем'єр-міністр Денис Шмигаль прибули до Нью-Йорка на засідання 77-ї Генасамблеї ООН, де представлятимуть Україну, - ЗМІ публікують відео. \n\nПовідомляється, що вже відбулась зустріч із генсеком ООН Антоніу Гуттерішем. \n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 10980                                                                                                                                                                                              🇺🇦🙌 Українські захисники поцілили у військову "комендатуру" в Сватовому на Луганщині та ліквідували пів сотні окупантів з технікою на Запоріжжі.\n\n"Підтверджено ураження місця зосередження особового складу у Пологівському районі, чисельністю понад 20 осіб; у Мелітопольському районі – складу боєприпасів, 5 одиниць військової техніки та понад 20 військовослужбовців; у районі населеного пункту Кам’янка – 10 одиниць військової техніки та понад 10 військовослужбовців підрозділів окупаційних військ".\n\n👉 Про це йдеться у ранковому зведенні Генштабу ЗСУ.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 10981                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            😡Росіяни обстріляли ЗАЕС: пошкоджено обладнання зв’язку одного з енергоблоків
# 10982                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            👉 ТСН.ua пропонує дізнатися головні події ночі, які ви могли проспати. https://bit.ly/3qVLtrY
# 10983  Ситуація на передовій чітко свідчить про те, що ініціатива – за Україною. Наші оборонці дуже акуратно й дуже хоробро виконують завдання, які ставить перед ними командування. Хочу сьогодні особливо відзначити 81-шу окрему десантно-штурмову бригаду – за сміливість при звільненні населених пунктів на Донеччині. А також 93-тю окрему механізовану бригаду – за героїчну оборону Бахмута і Соледара. Дякую вам! Дякую всім нашим героям!\n\nБільше підтримки для Збройних Сил України, більше підтримки для розвідки, більше підтримки для Сил спеціальних операцій, більше підтримки для СБУ, для Нацгвардії, для поліції, для прикордонників – для всіх, хто поступово відновлює нашу територіальну цілісність.\n\nСлава кожному й кожній, хто захищає державу! Слава нашому прекрасному народу!\nСлава Україні!
#
#         views  \
# 55     230149
# 56     222552
# 57     221416
# 58     213311
# 59     214135
# ...       ...
# 10979  182828
# 10980  212136
# 10981  215644
# 10982  217675
# 10983  202621
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       reactions
# 55                                                                                                                                   [{'_client': None, 'emoji': '👍', 'count': 2666, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 232, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 80, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 56, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 22, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 18, 'chosen': False}, {'_client': None, 'emoji': '🤩', 'count': 17, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 15, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 12, 'chosen': False}]
# 56     [{'_client': None, 'emoji': '👍', 'count': 3051, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 776, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 340, 'chosen': False}, {'_client': None, 'emoji': '🎉', 'count': 97, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 75, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 66, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 37, 'chosen': False}, {'_client': None, 'emoji': '🤣', 'count': 17, 'chosen': False}, {'_client': None, 'emoji': '😍', 'count': 16, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 14, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 8, 'chosen': False}]
# 57                                                                                                                                      [{'_client': None, 'emoji': '👍', 'count': 2424, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 426, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 79, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 48, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 22, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 13, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 9, 'chosen': False}, {'_client': None, 'emoji': '🤩', 'count': 5, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 3, 'chosen': False}]
# 58                                                                                                                                                                                                   [{'_client': None, 'emoji': '🤬', 'count': 2631, 'chosen': False}, {'_client': None, 'emoji': '😢', 'count': 927, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 177, 'chosen': False}, {'_client': None, 'emoji': '🤯', 'count': 40, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 22, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 11, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 7, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 6, 'chosen': False}]
# 59       [{'_client': None, 'emoji': '👍', 'count': 3415, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 826, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 120, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 63, 'chosen': False}, {'_client': None, 'emoji': '🤣', 'count': 14, 'chosen': False}, {'_client': None, 'emoji': '🤩', 'count': 12, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '🤬', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '🎉', 'count': 9, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 5, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 3, 'chosen': False}]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 10979       [{'_client': None, 'emoji': '👍', 'count': 3107, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 576, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 67, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 42, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 22, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 15, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 8, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 7, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 7, 'chosen': False}, {'_client': None, 'emoji': '🎉', 'count': 5, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 4, 'chosen': False}]
# 10980                                                                                                                                   [{'_client': None, 'emoji': '👍', 'count': 3054, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 614, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 174, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 71, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 31, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 8, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 2, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 1, 'chosen': False}]
# 10981    [{'_client': None, 'emoji': '🤬', 'count': 3286, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 401, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 61, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 46, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 38, 'chosen': False}, {'_client': None, 'emoji': '😢', 'count': 33, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 25, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 18, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 4, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 3, 'chosen': False}]
# 10982                                                                                                                                                                                                                                                                   [{'_client': None, 'emoji': '👍', 'count': 476, 'chosen': False}, {'_client': None, 'emoji': '❤', 'count': 52, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 29, 'chosen': False}, {'_client': None, 'emoji': '😁', 'count': 22, 'chosen': False}, {'_client': None, 'emoji': '😱', 'count': 6, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 3, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 2, 'chosen': False}]
# 10983  [{'_client': None, 'emoji': '❤', 'count': 3764, 'chosen': False}, {'_client': None, 'emoji': '👍', 'count': 934, 'chosen': False}, {'_client': None, 'emoji': '🔥', 'count': 82, 'chosen': False}, {'_client': None, 'emoji': '👏', 'count': 48, 'chosen': False}, {'_client': None, 'emoji': '🤡', 'count': 32, 'chosen': False}, {'_client': None, 'emoji': '🥰', 'count': 29, 'chosen': False}, {'_client': None, 'emoji': '👎', 'count': 13, 'chosen': False}, {'_client': None, 'emoji': '🤮', 'count': 13, 'chosen': False}, {'_client': None, 'emoji': '🤔', 'count': 12, 'chosen': False}, {'_client': None, 'emoji': '😢', 'count': 10, 'chosen': False}, {'_client': None, 'emoji': '💩', 'count': 10, 'chosen': False}]
#
# [10929 rows x 5 columns]

# %%
# these are standard telegram reactions emojis
# clown emoji was premium reaction until Sep 18, but still it was very popular

recorded_emoji = ['🤡','👍', '👎', '❤', '🔥', '🥰', '👏', '😁', '🤔', '🤯', '😱', '🤬', '😢', '🎉', '🤩', '🤮', '💩']
recorded_emoji_set = set(recorded_emoji)

# %%
empty_reactions_indexes = [] # don't see any other way but to use global variable for this, walrus(:=) is not working in colab

def standardize_reaction(data):
  i = 0
  #empty_reactions_indexes = []
  for index, val in data.reactions.items():
    i += 1
    #print(i)
    s = str(val).replace('None', 'null')
    s = s.replace('False', 'false')
    s = s.replace('True', 'true')
    s = s.replace('\'', '\"')
    s = s.replace('\\', '')
    reaction = pd.read_json(s, orient = 'records', encoding_errors = 'backslashreplace')

    if reaction.empty:
      empty_reactions_indexes.append(i - 1)
      standardized_reaction = pd.DataFrame(data=0, 
                                        index = ['count'], columns=recorded_emoji)
    else:
      reaction.drop(columns = ['_client', 'chosen'], inplace = True)
      reaction = reaction.T
      reaction.columns = reaction.iloc[0]
      reaction.drop('emoji', inplace = True)

      standardized_reaction = pd.DataFrame(data=0, 
                                          index = ['count'], columns=recorded_emoji)
      for emj, cnt in reaction.iteritems():
        if emj in recorded_emoji_set:
          standardized_reaction[emj] = cnt
      standardized_reaction.loc['count'] /= standardized_reaction.loc['count'].sum()
    
    yield standardized_reaction
    #

# %%
reactions_divided = pd.DataFrame()

reactions_divided = pd.concat([std_reaction for std_reaction in standardize_reaction(data)], copy=False)

# %%
reactions_divided
# Out:
#               🤡         👍         👎         ❤         🔥         🥰         👏  \
# count         0  0.855035  0.007056  0.074407  0.025657  0.003849  0.004811
# count         0  0.683468  0.003136  0.016801  0.173835  0.076165  0.008289
# count         0  0.800264         0   0.14064  0.026081         0  0.015847
# count         0  0.046323   0.00157  0.002879         0         0  0.001832
# count         0   0.76347  0.000671  0.184664  0.014085  0.026828         0
# ...         ...       ...       ...       ...       ...       ...       ...
# count  0.001813  0.804922  0.002073  0.149223  0.003886  0.017358  0.010881
# count  0.002022  0.771797  0.000505  0.043973  0.155168  0.007834  0.017943
# count  0.009682   0.01172  0.004586         0         0  0.000764  0.001019
# count         0   0.80678         0  0.088136  0.005085         0   0.00339
# count  0.006469  0.188801  0.002628  0.760865  0.016576  0.005862  0.009703
#
#               😁         🤔         🤯         😱         🤬         😢         🎉  \
# count   0.01796  0.005773         0         0         0         0         0
# count  0.014785         0         0  0.001792         0         0  0.021729
# count   0.00099  0.007263         0         0         0         0         0
# count         0         0  0.010468  0.005758  0.688563  0.242607         0
# count         0  0.002236         0         0  0.002236         0  0.002012
# ...         ...       ...       ...       ...       ...       ...       ...
# count  0.001813         0         0         0         0         0  0.001295
# count         0  0.000253         0  0.000505         0         0         0
# count  0.002548         0         0  0.102166  0.837197  0.008408         0
# count  0.037288  0.049153         0  0.010169         0         0         0
# count         0  0.002426         0         0         0  0.002021         0
#
#               🤩         🤮         💩
# count  0.005452         0         0
# count         0         0         0
# count  0.001651  0.002971  0.004292
# count         0         0         0
# count  0.002683         0  0.001118
# ...         ...       ...       ...
# count         0  0.005699  0.001036
# count         0         0         0
# count         0  0.006369  0.015541
# count         0         0         0
# count         0  0.002628  0.002021
#
# [10929 rows x 17 columns]

# %%
empty_reactions_indexes
# Out:
# []

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.8/dist-packages (2.2.0)

# %%
import emoji

reactions_divided.columns = [emoji.demojize(emj, delimiters = ('', '')) for emj in reactions_divided.columns]

# %%
data.drop(['message_id', 'date', 'reactions'], axis=1, inplace=True)

# %%
[data.columns, reactions_divided.columns]
# Out:
# [Index(['msg_text', 'views'], dtype='object'),
#  Index(['clown_face', 'thumbs_up', 'thumbs_down', 'red_heart', 'fire',
#         'smiling_face_with_hearts', 'clapping_hands',
#         'beaming_face_with_smiling_eyes', 'thinking_face', 'exploding_head',
#         'face_screaming_in_fear', 'face_with_symbols_on_mouth', 'crying_face',
#         'party_popper', 'star-struck', 'face_vomiting', 'pile_of_poo'],
#        dtype='object')]

# %%
data_f = pd.concat([data.reset_index(drop = True), reactions_divided.reset_index(drop = True)], axis = 1)
data_f
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       msg_text  \
# 0                                                                                                                                                                                                                                                                                                                              Міноборони висміяло фейки РФ про "знищені" M142 HIMARS та "вбитих" українських військових\n\n""Знищені", згідно з заявами російського Міноборони, HIMARS щодня спалюють склади та казарми окупантів. Сотні нібито "убитих" українських солдатів відбивають атаки рашистських смертників у Бахмуті та Соледарі. Історія знає битви, виграні за допомогою підступності. Але брехня щоразу перемагає саму себе", - зазначили у Міноборони України.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ❗️ Вибухи в Бєлгородській області\n\nГучно цього вечора відразу в декількох населених пунктах регіону РФ, повідомляють місцеві. \n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Challenger 2: що відомо про танк, який Велика Британія може надіслати ЗСУ\n\nСполучене Королівство може стати першою країною, яка відправить ЗСУ власні танки для протистояння РФ. Про основні характеристики танку Challenger 2 читайте в матеріалі ТСН.uа.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    🤬 Ракетний удар по Краматорську. Окупанти влучили у проїжджу частину та автомобіль, - Офіс президента. \n\nЗагинули двоє людей, які перебували в автівці.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        🇺🇦🇬🇧 Велика Британія у 2023 хоче досягти або перевищити минулорічний рівень надання допомоги Україні \n\nПро це повідомляє британське Міністерство оборони. Там запевняють, що непохитно підтримуватимуть Україну для захисту від РФ.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 10924                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          🇺🇳🇺🇸 Перша леді Олена Зеленська та прем'єр-міністр Денис Шмигаль прибули до Нью-Йорка на засідання 77-ї Генасамблеї ООН, де представлятимуть Україну, - ЗМІ публікують відео. \n\nПовідомляється, що вже відбулась зустріч із генсеком ООН Антоніу Гуттерішем. \n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 10925                                                                                                                                                                                              🇺🇦🙌 Українські захисники поцілили у військову "комендатуру" в Сватовому на Луганщині та ліквідували пів сотні окупантів з технікою на Запоріжжі.\n\n"Підтверджено ураження місця зосередження особового складу у Пологівському районі, чисельністю понад 20 осіб; у Мелітопольському районі – складу боєприпасів, 5 одиниць військової техніки та понад 20 військовослужбовців; у районі населеного пункту Кам’янка – 10 одиниць військової техніки та понад 10 військовослужбовців підрозділів окупаційних військ".\n\n👉 Про це йдеться у ранковому зведенні Генштабу ЗСУ.\n\nПідписатися| YouTube ТСН | Підтримати ТСН.ua
# 10926                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            😡Росіяни обстріляли ЗАЕС: пошкоджено обладнання зв’язку одного з енергоблоків
# 10927                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            👉 ТСН.ua пропонує дізнатися головні події ночі, які ви могли проспати. https://bit.ly/3qVLtrY
# 10928  Ситуація на передовій чітко свідчить про те, що ініціатива – за Україною. Наші оборонці дуже акуратно й дуже хоробро виконують завдання, які ставить перед ними командування. Хочу сьогодні особливо відзначити 81-шу окрему десантно-штурмову бригаду – за сміливість при звільненні населених пунктів на Донеччині. А також 93-тю окрему механізовану бригаду – за героїчну оборону Бахмута і Соледара. Дякую вам! Дякую всім нашим героям!\n\nБільше підтримки для Збройних Сил України, більше підтримки для розвідки, більше підтримки для Сил спеціальних операцій, більше підтримки для СБУ, для Нацгвардії, для поліції, для прикордонників – для всіх, хто поступово відновлює нашу територіальну цілісність.\n\nСлава кожному й кожній, хто захищає державу! Слава нашому прекрасному народу!\nСлава Україні!
#
#         views clown_face thumbs_up thumbs_down red_heart      fire  \
# 0      230149          0  0.855035    0.007056  0.074407  0.025657
# 1      222552          0  0.683468    0.003136  0.016801  0.173835
# 2      221416          0  0.800264           0   0.14064  0.026081
# 3      213311          0  0.046323     0.00157  0.002879         0
# 4      214135          0   0.76347    0.000671  0.184664  0.014085
# ...       ...        ...       ...         ...       ...       ...
# 10924  182828   0.001813  0.804922    0.002073  0.149223  0.003886
# 10925  212136   0.002022  0.771797    0.000505  0.043973  0.155168
# 10926  215644   0.009682   0.01172    0.004586         0         0
# 10927  217675          0   0.80678           0  0.088136  0.005085
# 10928  202621   0.006469  0.188801    0.002628  0.760865  0.016576
#
#       smiling_face_with_hearts clapping_hands beaming_face_with_smiling_eyes  \
# 0                     0.003849       0.004811                        0.01796
# 1                     0.076165       0.008289                       0.014785
# 2                            0       0.015847                        0.00099
# 3                            0       0.001832                              0
# 4                     0.026828              0                              0
# ...                        ...            ...                            ...
# 10924                 0.017358       0.010881                       0.001813
# 10925                 0.007834       0.017943                              0
# 10926                 0.000764       0.001019                       0.002548
# 10927                        0        0.00339                       0.037288
# 10928                 0.005862       0.009703                              0
#
#       thinking_face exploding_head face_screaming_in_fear  \
# 0          0.005773              0                      0
# 1                 0              0               0.001792
# 2          0.007263              0                      0
# 3                 0       0.010468               0.005758
# 4          0.002236              0                      0
# ...             ...            ...                    ...
# 10924             0              0                      0
# 10925      0.000253              0               0.000505
# 10926             0              0               0.102166
# 10927      0.049153              0               0.010169
# 10928      0.002426              0                      0
#
#       face_with_symbols_on_mouth crying_face party_popper star-struck  \
# 0                              0           0            0    0.005452
# 1                              0           0     0.021729           0
# 2                              0           0            0    0.001651
# 3                       0.688563    0.242607            0           0
# 4                       0.002236           0     0.002012    0.002683
# ...                          ...         ...          ...         ...
# 10924                          0           0     0.001295           0
# 10925                          0           0            0           0
# 10926                   0.837197    0.008408            0           0
# 10927                          0           0            0           0
# 10928                          0    0.002021            0           0
#
#       face_vomiting pile_of_poo
# 0                 0           0
# 1                 0           0
# 2          0.002971    0.004292
# 3                 0           0
# 4                 0    0.001118
# ...             ...         ...
# 10924      0.005699    0.001036
# 10925             0           0
# 10926      0.006369    0.015541
# 10927             0           0
# 10928      0.002628    0.002021
#
# [10929 rows x 19 columns]

# %%
data_f.iloc[empty_reactions_indexes, :]
# Out:
# Empty DataFrame
# Columns: [msg_text, views, clown_face, thumbs_up, thumbs_down, red_heart, fire, smiling_face_with_hearts, clapping_hands, beaming_face_with_smiling_eyes, thinking_face, exploding_head, face_screaming_in_fear, face_with_symbols_on_mouth, crying_face, party_popper, star-struck, face_vomiting, pile_of_poo]
# Index: []

# %%
data_f.drop(axis = 0, index = empty_reactions_indexes, inplace = True)

# %%
data_f.msg_text = data_f.msg_text.astype('string', copy = False)

# %%
data_f.msg_text
# Out:
# 0                                                                                                                                                                                                                                                                                                                               Міноборони висміяло фейки РФ про "знищені" M142 HIMARS та "вбитих" українських військових
#
# ""Знищені", згідно з заявами російського Міноборони, HIMARS щодня спалюють склади та казарми окупантів. Сотні нібито "убитих" українських солдатів відбивають атаки рашистських смертників у Бахмуті та Соледарі. Історія знає битви, виграні за допомогою підступності. Але брехня щоразу перемагає саму себе", - зазначили у Міноборони України.
#
# Підписатися| YouTube ТСН | Підтримати ТСН.ua
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ❗️ Вибухи в Бєлгородській області
#
# Гучно цього вечора відразу в декількох населених пунктах регіону РФ, повідомляють місцеві.
#
# Підписатися| YouTube ТСН | Підтримати ТСН.ua
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Challenger 2: що відомо про танк, який Велика Британія може надіслати ЗСУ
#
# Сполучене Королівство може стати першою країною, яка відправить ЗСУ власні танки для протистояння РФ. Про основні характеристики танку Challenger 2 читайте в матеріалі ТСН.uа.
#
# Підписатися| YouTube ТСН | Підтримати ТСН.ua
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     🤬 Ракетний удар по Краматорську. Окупанти влучили у проїжджу частину та автомобіль, - Офіс президента.
#
# Загинули двоє людей, які перебували в автівці.
#
# Підписатися| YouTube ТСН | Підтримати ТСН.ua
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         🇺🇦🇬🇧 Велика Британія у 2023 хоче досягти або перевищити минулорічний рівень надання допомоги Україні
#
# Про це повідомляє британське Міністерство оборони. Там запевняють, що непохитно підтримуватимуть Україну для захисту від РФ.
#
# Підписатися| YouTube ТСН | Підтримати ТСН.ua
#                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 10924                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           🇺🇳🇺🇸 Перша леді Олена Зеленська та прем'єр-міністр Денис Шмигаль прибули до Нью-Йорка на засідання 77-ї Генасамблеї ООН, де представлятимуть Україну, - ЗМІ публікують відео.
#
# Повідомляється, що вже відбулась зустріч із генсеком ООН Антоніу Гуттерішем.
#
# Підписатися| YouTube ТСН | Підтримати ТСН.ua
# 10925                                                                                                                                                                                                 🇺🇦🙌 Українські захисники поцілили у військову "комендатуру" в Сватовому на Луганщині та ліквідували пів сотні окупантів з технікою на Запоріжжі.
#
# "Підтверджено ураження місця зосередження особового складу у Пологівському районі, чисельністю понад 20 осіб; у Мелітопольському районі – складу боєприпасів, 5 одиниць військової техніки та понад 20 військовослужбовців; у районі населеного пункту Кам’янка – 10 одиниць військової техніки та понад 10 військовослужбовців підрозділів окупаційних військ".
#
# 👉 Про це йдеться у ранковому зведенні Генштабу ЗСУ.
#
# Підписатися| YouTube ТСН | Підтримати ТСН.ua
# 10926                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         😡Росіяни обстріляли ЗАЕС: пошкоджено обладнання зв’язку одного з енергоблоків
# 10927                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         👉 ТСН.ua пропонує дізнатися головні події ночі, які ви могли проспати. https://bit.ly/3qVLtrY
# 10928    Ситуація на передовій чітко свідчить про те, що ініціатива – за Україною. Наші оборонці дуже акуратно й дуже хоробро виконують завдання, які ставить перед ними командування. Хочу сьогодні особливо відзначити 81-шу окрему десантно-штурмову бригаду – за сміливість при звільненні населених пунктів на Донеччині. А також 93-тю окрему механізовану бригаду – за героїчну оборону Бахмута і Соледара. Дякую вам! Дякую всім нашим героям!
#
# Більше підтримки для Збройних Сил України, більше підтримки для розвідки, більше підтримки для Сил спеціальних операцій, більше підтримки для СБУ, для Нацгвардії, для поліції, для прикордонників – для всіх, хто поступово відновлює нашу територіальну цілісність.
#
# Слава кожному й кожній, хто захищає державу! Слава нашому прекрасному народу!
# Слава Україні!
# Name: msg_text, Length: 10929, dtype: string

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def preprocess_text(text):
  import re
  import string

  new_text = emoji.replace_emoji(text, replace = '')
  new_text = new_text.replace('\n', ' ')
  new_text = new_text.lower()
  new_text = re.sub(r'http\S+', '', new_text)

  # deleting all punctuation
  mappingtbl = new_text.maketrans({punct: ' ' for punct in string.punctuation + '–—«»№₤€'})
  new_text = new_text.translate(mappingtbl)
  
  # removing multiple spaces
  new_text = ' '.join(new_text.split())
  
  # There can be text with hyperlinks in the end of news
  # that have such content: "підписатися youtube тсн підтримати тсн ua"
  # we need to delete it as well
  new_text = new_text.replace('підписатися youtube тсн підтримати тсн ua', ' ')

  # removing multiple spaces second time
  new_text = ' '.join(new_text.split())

  return new_text

# %%
s = data_f.msg_text.iloc[-1]
print(preprocess_text(s))
s
# Out:
# ситуація на передовій чітко свідчить про те що ініціатива за україною наші оборонці дуже акуратно й дуже хоробро виконують завдання які ставить перед ними командування хочу сьогодні особливо відзначити 81 шу окрему десантно штурмову бригаду за сміливість при звільненні населених пунктів на донеччині а також 93 тю окрему механізовану бригаду за героїчну оборону бахмута і соледара дякую вам дякую всім нашим героям більше підтримки для збройних сил україни більше підтримки для розвідки більше підтримки для сил спеціальних операцій більше підтримки для сбу для нацгвардії для поліції для прикордонників для всіх хто поступово відновлює нашу територіальну цілісність слава кожному й кожній хто захищає державу слава нашому прекрасному народу слава україні
# 'Ситуація на передовій чітко свідчить про те, що ініціатива – за Україною. Наші оборонці дуже акуратно й дуже хоробро виконують завдання, які ставить перед ними командування. Хочу сьогодні особливо відзначити 81-шу окрему десантно-штурмову бригаду – за сміливість при звільненні населених пунктів на Донеччині. А також 93-тю окрему механізовану бригаду – за героїчну оборону Бахмута і Соледара. Дякую вам! Дякую всім нашим героям!\n\nБільше підтримки для Збройних Сил України, більше підтримки для розвідки, більше підтримки для Сил спеціальних операцій, більше підтримки для СБУ, для Нацгвардії, для поліції, для прикордонників – для всіх, хто поступово відновлює нашу територіальну цілісність.\n\nСлава кожному й кожній, хто захищає державу! Слава нашому прекрасному народу!\nСлава Україні!'

# %%
data_f.msg_text = data_f.msg_text.apply(preprocess_text)

# %%
data_f
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    msg_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                  міноборони висміяло фейки рф про знищені m142 himars та вбитих українських військових знищені згідно з заявами російського міноборони himars щодня спалюють склади та казарми окупантів сотні нібито убитих українських солдатів відбивають атаки рашистських смертників у бахмуті та соледарі історія знає битви виграні за допомогою підступності але брехня щоразу перемагає саму себе зазначили у міноборони україни
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   вибухи в бєлгородській області гучно цього вечора відразу в декількох населених пунктах регіону рф повідомляють місцеві
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      challenger 2 що відомо про танк який велика британія може надіслати зсу сполучене королівство може стати першою країною яка відправить зсу власні танки для протистояння рф про основні характеристики танку challenger 2 читайте в матеріалі тсн uа
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ракетний удар по краматорську окупанти влучили у проїжджу частину та автомобіль офіс президента загинули двоє людей які перебували в автівці
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 велика британія у 2023 хоче досягти або перевищити минулорічний рівень надання допомоги україні про це повідомляє британське міністерство оборони там запевняють що непохитно підтримуватимуть україну для захисту від рф
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 10924                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        перша леді олена зеленська та прем єр міністр денис шмигаль прибули до нью йорка на засідання 77 ї генасамблеї оон де представлятимуть україну змі публікують відео повідомляється що вже відбулась зустріч із генсеком оон антоніу гуттерішем
# 10925                                                                                                                                                                                                                                      українські захисники поцілили у військову комендатуру в сватовому на луганщині та ліквідували пів сотні окупантів з технікою на запоріжжі підтверджено ураження місця зосередження особового складу у пологівському районі чисельністю понад 20 осіб у мелітопольському районі складу боєприпасів 5 одиниць військової техніки та понад 20 військовослужбовців у районі населеного пункту кам’янка 10 одиниць військової техніки та понад 10 військовослужбовців підрозділів окупаційних військ про це йдеться у ранковому зведенні генштабу зсу
# 10926                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           росіяни обстріляли заес пошкоджено обладнання зв’язку одного з енергоблоків
# 10927                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    тсн ua пропонує дізнатися головні події ночі які ви могли проспати
# 10928  ситуація на передовій чітко свідчить про те що ініціатива за україною наші оборонці дуже акуратно й дуже хоробро виконують завдання які ставить перед ними командування хочу сьогодні особливо відзначити 81 шу окрему десантно штурмову бригаду за сміливість при звільненні населених пунктів на донеччині а також 93 тю окрему механізовану бригаду за героїчну оборону бахмута і соледара дякую вам дякую всім нашим героям більше підтримки для збройних сил україни більше підтримки для розвідки більше підтримки для сил спеціальних операцій більше підтримки для сбу для нацгвардії для поліції для прикордонників для всіх хто поступово відновлює нашу територіальну цілісність слава кожному й кожній хто захищає державу слава нашому прекрасному народу слава україні
#
#         views clown_face thumbs_up thumbs_down red_heart      fire  \
# 0      230149          0  0.855035    0.007056  0.074407  0.025657
# 1      222552          0  0.683468    0.003136  0.016801  0.173835
# 2      221416          0  0.800264           0   0.14064  0.026081
# 3      213311          0  0.046323     0.00157  0.002879         0
# 4      214135          0   0.76347    0.000671  0.184664  0.014085
# ...       ...        ...       ...         ...       ...       ...
# 10924  182828   0.001813  0.804922    0.002073  0.149223  0.003886
# 10925  212136   0.002022  0.771797    0.000505  0.043973  0.155168
# 10926  215644   0.009682   0.01172    0.004586         0         0
# 10927  217675          0   0.80678           0  0.088136  0.005085
# 10928  202621   0.006469  0.188801    0.002628  0.760865  0.016576
#
#       smiling_face_with_hearts clapping_hands beaming_face_with_smiling_eyes  \
# 0                     0.003849       0.004811                        0.01796
# 1                     0.076165       0.008289                       0.014785
# 2                            0       0.015847                        0.00099
# 3                            0       0.001832                              0
# 4                     0.026828              0                              0
# ...                        ...            ...                            ...
# 10924                 0.017358       0.010881                       0.001813
# 10925                 0.007834       0.017943                              0
# 10926                 0.000764       0.001019                       0.002548
# 10927                        0        0.00339                       0.037288
# 10928                 0.005862       0.009703                              0
#
#       thinking_face exploding_head face_screaming_in_fear  \
# 0          0.005773              0                      0
# 1                 0              0               0.001792
# 2          0.007263              0                      0
# 3                 0       0.010468               0.005758
# 4          0.002236              0                      0
# ...             ...            ...                    ...
# 10924             0              0                      0
# 10925      0.000253              0               0.000505
# 10926             0              0               0.102166
# 10927      0.049153              0               0.010169
# 10928      0.002426              0                      0
#
#       face_with_symbols_on_mouth crying_face party_popper star-struck  \
# 0                              0           0            0    0.005452
# 1                              0           0     0.021729           0
# 2                              0           0            0    0.001651
# 3                       0.688563    0.242607            0           0
# 4                       0.002236           0     0.002012    0.002683
# ...                          ...         ...          ...         ...
# 10924                          0           0     0.001295           0
# 10925                          0           0            0           0
# 10926                   0.837197    0.008408            0           0
# 10927                          0           0            0           0
# 10928                          0    0.002021            0           0
#
#       face_vomiting pile_of_poo
# 0                 0           0
# 1                 0           0
# 2          0.002971    0.004292
# 3                 0           0
# 4                 0    0.001118
# ...             ...         ...
# 10924      0.005699    0.001036
# 10925             0           0
# 10926      0.006369    0.015541
# 10927             0           0
# 10928      0.002628    0.002021
#
# [10929 rows x 19 columns]

# %%
pd.set_option('display.max_colwidth', None)
data_f.msg_text
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                    міноборони висміяло фейки рф про знищені m142 himars та вбитих українських військових знищені згідно з заявами російського міноборони himars щодня спалюють склади та казарми окупантів сотні нібито убитих українських солдатів відбивають атаки рашистських смертників у бахмуті та соледарі історія знає битви виграні за допомогою підступності але брехня щоразу перемагає саму себе зазначили у міноборони україни
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     вибухи в бєлгородській області гучно цього вечора відразу в декількох населених пунктах регіону рф повідомляють місцеві
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        challenger 2 що відомо про танк який велика британія може надіслати зсу сполучене королівство може стати першою країною яка відправить зсу власні танки для протистояння рф про основні характеристики танку challenger 2 читайте в матеріалі тсн uа
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ракетний удар по краматорську окупанти влучили у проїжджу частину та автомобіль офіс президента загинули двоє людей які перебували в автівці
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   велика британія у 2023 хоче досягти або перевищити минулорічний рівень надання допомоги україні про це повідомляє британське міністерство оборони там запевняють що непохитно підтримуватимуть україну для захисту від рф
#                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 10924                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          перша леді олена зеленська та прем єр міністр денис шмигаль прибули до нью йорка на засідання 77 ї генасамблеї оон де представлятимуть україну змі публікують відео повідомляється що вже відбулась зустріч із генсеком оон антоніу гуттерішем
# 10925                                                                                                                                                                                                                                        українські захисники поцілили у військову комендатуру в сватовому на луганщині та ліквідували пів сотні окупантів з технікою на запоріжжі підтверджено ураження місця зосередження особового складу у пологівському районі чисельністю понад 20 осіб у мелітопольському районі складу боєприпасів 5 одиниць військової техніки та понад 20 військовослужбовців у районі населеного пункту кам’янка 10 одиниць військової техніки та понад 10 військовослужбовців підрозділів окупаційних військ про це йдеться у ранковому зведенні генштабу зсу
# 10926                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             росіяни обстріляли заес пошкоджено обладнання зв’язку одного з енергоблоків
# 10927                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      тсн ua пропонує дізнатися головні події ночі які ви могли проспати
# 10928    ситуація на передовій чітко свідчить про те що ініціатива за україною наші оборонці дуже акуратно й дуже хоробро виконують завдання які ставить перед ними командування хочу сьогодні особливо відзначити 81 шу окрему десантно штурмову бригаду за сміливість при звільненні населених пунктів на донеччині а також 93 тю окрему механізовану бригаду за героїчну оборону бахмута і соледара дякую вам дякую всім нашим героям більше підтримки для збройних сил україни більше підтримки для розвідки більше підтримки для сил спеціальних операцій більше підтримки для сбу для нацгвардії для поліції для прикордонників для всіх хто поступово відновлює нашу територіальну цілісність слава кожному й кожній хто захищає державу слава нашому прекрасному народу слава україні
# Name: msg_text, Length: 10929, dtype: object

# %%
data_f.drop(columns = 'views', inplace = True)

# %%
data_f.drop(data_f[data_f.msg_text == ''].index, inplace = True)

# %%
data_f.reset_index(drop = True, inplace = True)

# %%
data_f.to_csv('/content/drive/My Drive/reaction_prediction/tsn_reactions_dataset_from_Sep_21.csv')

# %%
# !ls /content/drive/My\ Drive/reaction_prediction
# Out:
# clear_dataset_from_2_jul.json	      stopwords.txt
# clear_dataset_from_Sep_21.json	      train_set.csv
# clear_dataset.json		      tsn_reactions_dataset.csv
# concatenated_pos_neg.csv	      tsn_reactions_dataset_from_2_jul.csv
# model.joblib			      tsn_reactions_dataset_from_Sep_21.csv
# news.lowercased.tokenized.glove.300d  vectorizer.joblib
