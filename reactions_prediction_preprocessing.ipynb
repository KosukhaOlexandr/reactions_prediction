# %% [markdown]
# <a href="https://colab.research.google.com/github/KosukhaOlexandr/reactions_prediction/blob/main/reactions_prediction_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

with open('/content/drive/MyDrive/reaction_prediction/clear_dataset_from_2_jul.json') as f:
  data = pd.read_json(f,  orient = 'records')

# %%
data
# Out:
#        message_id                date  \
# 0           53938 2022-09-21 21:40:19
# 1           53937 2022-09-21 21:34:04
# 2           53935 2022-09-21 21:22:41
# 3           53934 2022-09-21 21:15:03
# 4           53931 2022-09-21 21:09:34
# ...           ...                 ...
# 10258       38771 2022-07-02 02:04:22
# 10259       38770 2022-07-02 01:31:29
# 10260       38769 2022-07-02 01:07:27
# 10261       38768 2022-07-02 00:45:05
# 10262       38767 2022-07-02 00:33:23
#
#                                                 msg_text   views  \
# 0                😁🇺🇦 Ми українці і гумор у нас в крові !    3003
# 1      ‼️Останні ядерні погрози Путіна "типові", але ...   29034
# 2            Коротко про сьогоднішні протести у росіян 🤡   52400
# 3      🙌🇫🇮 У Фінляндії виступили за закриття кордонів...   65057
# 4      ❗️Силовики розігнали мітинги вже майже у всіх ...   71389
# ...                                                  ...     ...
# 10258  У п'ятницю, 1 липня, російські окупанти випуст...  198618
# 10259  ЮНЕСКО остаточно внесла українську національну...  206802
# 10260  Президент США Джо Байден повідомив про новий п...  206527
# 10261  В Україні стартував сезон малини. Проте аромат...  212290
# 10262  У ЗСУ розповіли про джерела, з яких дізнаються...  218062
#
#                                                reactions
# 0      [{'_client': None, 'emoji': '👍', 'count': 1, '...
# 1      [{'_client': None, 'emoji': '👍', 'count': 379,...
# 2      [{'_client': None, 'emoji': '😁', 'count': 1049...
# 3      [{'_client': None, 'emoji': '👍', 'count': 2283...
# 4      [{'_client': None, 'emoji': '🤡', 'count': 2183...
# ...                                                  ...
# 10258  [{'_client': None, 'emoji': '🤬', 'count': 2046...
# 10259  [{'_client': None, 'emoji': '❤', 'count': 3153...
# 10260  [{'_client': None, 'emoji': '👍', 'count': 1976...
# 10261  [{'_client': None, 'emoji': '❤', 'count': 1206...
# 10262  [{'_client': None, 'emoji': '👍', 'count': 1196...
#
# [10263 rows x 5 columns]

# %% [markdown]
# we need to delete posts from the last day to prevent undervoting in data

# %%
data.drop(data[data['date'].dt.date == data['date'].iloc[0].date()].index, inplace = True)

# %%
data
# Out:
#        message_id                date  \
# 122         53688 2022-09-20 23:58:09
# 123         53687 2022-09-20 23:40:08
# 124         53686 2022-09-20 23:23:32
# 125         53685 2022-09-20 23:12:07
# 126         53684 2022-09-20 22:57:19
# ...           ...                 ...
# 10258       38771 2022-07-02 02:04:22
# 10259       38770 2022-07-02 01:31:29
# 10260       38769 2022-07-02 01:07:27
# 10261       38768 2022-07-02 00:45:05
# 10262       38767 2022-07-02 00:33:23
#
#                                                 msg_text   views  \
# 122    😂 Користувачі соцмереж в очікуванні звернення ...  205495
# 123    🤬 Російські загарбники продовжують "мобілізаці...  203217
# 124    ❗️Місцеві канали повідомляють про звуки вибухі...  205310
# 125    ❗️Окупанти б’ють ракетами по дамбі на Харківщи...  210989
# 126    ‼️ Українським громадянам влада рекомендує не ...  215432
# ...                                                  ...     ...
# 10258  У п'ятницю, 1 липня, російські окупанти випуст...  198618
# 10259  ЮНЕСКО остаточно внесла українську національну...  206802
# 10260  Президент США Джо Байден повідомив про новий п...  206527
# 10261  В Україні стартував сезон малини. Проте аромат...  212290
# 10262  У ЗСУ розповіли про джерела, з яких дізнаються...  218062
#
#                                                reactions
# 122    [{'_client': None, 'emoji': '🤣', 'count': 2882...
# 123    [{'_client': None, 'emoji': '🤬', 'count': 1756...
# 124    [{'_client': None, 'emoji': '🤬', 'count': 1998...
# 125    [{'_client': None, 'emoji': '🤬', 'count': 3120...
# 126    [{'_client': None, 'emoji': '👍', 'count': 2646...
# ...                                                  ...
# 10258  [{'_client': None, 'emoji': '🤬', 'count': 2046...
# 10259  [{'_client': None, 'emoji': '❤', 'count': 3153...
# 10260  [{'_client': None, 'emoji': '👍', 'count': 1976...
# 10261  [{'_client': None, 'emoji': '❤', 'count': 1206...
# 10262  [{'_client': None, 'emoji': '👍', 'count': 1196...
#
# [10141 rows x 5 columns]

# %%
# these are standard telegram reactions emojis
# clown emoji was premium reaction until Sep 18, but still it was very popular

recorded_emoji = ['🤡','👍', '👎', '❤', '🔥', '🥰', '👏', '😁', '🤔', '🤯', '😱', '🤬', '😢', '🎉', '🤩', '🤮', '💩']
recorded_emoji_set = set(recorded_emoji)

# %%
empty_reactions_indexes = [] # don't see any other way but to use global variable for this, walrus(:=) is not working in colab

def standardize_reaction(data):
  i = 0
  #empty_reactions_indexes = []
  for index, val in data.reactions.items():
    i += 1
    #print(i)
    s = str(val).replace('None', 'null')
    s = s.replace('False', 'false')
    s = s.replace('True', 'true')
    s = s.replace('\'', '\"')
    s = s.replace('\\', '')
    reaction = pd.read_json(s, orient = 'records', encoding_errors = 'backslashreplace')

    if reaction.empty:
      empty_reactions_indexes.append(i - 1)
      standardized_reaction = pd.DataFrame(data=0, 
                                        index = ['count'], columns=recorded_emoji)
    else:
      reaction.drop(columns = ['_client', 'chosen'], inplace = True)
      reaction = reaction.T
      reaction.columns = reaction.iloc[0]
      reaction.drop('emoji', inplace = True)

      standardized_reaction = pd.DataFrame(data=0, 
                                          index = ['count'], columns=recorded_emoji)
      for emj, cnt in reaction.iteritems():
        if emj in recorded_emoji_set:
          standardized_reaction[emj] = cnt
      standardized_reaction.loc['count'] /= standardized_reaction.loc['count'].sum()
    
    yield standardized_reaction
    #

# %%
reactions_divided = pd.DataFrame()

reactions_divided = pd.concat([std_reaction for std_reaction in standardize_reaction(data)], copy=False)

# %%
reactions_divided
# Out:
#               🤡         👍         👎         ❤         🔥         🥰         👏  \
# count  0.042216  0.525066         0  0.047493  0.025066   0.01847  0.019789
# count  0.011671  0.111578         0  0.004202  0.009337  0.003735  0.001401
# count  0.003957   0.03522  0.003166  0.003562         0  0.007519   0.00277
# count         0  0.042405  0.003742  0.002494  0.002744         0  0.001996
# count  0.003946  0.870109  0.003288  0.071358  0.003946  0.000987  0.020059
# ...         ...       ...       ...       ...       ...       ...       ...
# count         0  0.064867         0  0.004939  0.002305         0         0
# count         0  0.143517   0.00154  0.809499  0.003338  0.015918  0.012837
# count         0  0.856524  0.001734  0.095362  0.022107         0  0.015605
# count         0  0.182081  0.005202   0.69711  0.005202  0.012717         0
# count         0  0.664076         0   0.02332  0.003887  0.001666         0
#
#               😁         🤔         🤯         😱         🤬         😢         🎉  \
# count  0.277045   0.01847         0         0         0         0  0.005277
# count         0  0.005135  0.028945  0.004202  0.819795         0         0
# count         0         0  0.004353  0.006332  0.790661  0.130985         0
# count         0  0.002993  0.004739  0.106261  0.778249  0.048391         0
# count  0.011181  0.009865         0         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# count         0  0.005927         0  0.006915  0.673691  0.240698         0
# count  0.006932  0.002567         0         0         0         0         0
# count  0.004768  0.001734         0         0  0.000433         0         0
# count         0  0.002312         0  0.016185         0  0.066474         0
# count  0.003331  0.007218  0.004442         0  0.037202   0.24764         0
#
#        🤩         🤮         💩
# count  0  0.021108         0
# count  0         0         0
# count  0         0  0.011476
# count  0         0  0.005987
# count  0  0.005261         0
# ...   ..       ...       ...
# count  0  0.000659         0
# count  0         0  0.003851
# count  0  0.001734         0
# count  0  0.005202  0.007514
# count  0  0.003887  0.003331
#
# [10141 rows x 17 columns]

# %%
empty_reactions_indexes
# Out:
# []

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (2.1.0)

# %%
import emoji

reactions_divided.columns = [emoji.demojize(emj, delimiters = ('', '')) for emj in reactions_divided.columns]

# %%
data.drop(['message_id', 'date', 'reactions'], axis=1, inplace=True)

# %%
[data.columns, reactions_divided.columns]
# Out:
# [Index(['msg_text', 'views'], dtype='object'),
#  Index(['clown_face', 'thumbs_up', 'thumbs_down', 'red_heart', 'fire',
#         'smiling_face_with_hearts', 'clapping_hands',
#         'beaming_face_with_smiling_eyes', 'thinking_face', 'exploding_head',
#         'face_screaming_in_fear', 'face_with_symbols_on_mouth', 'crying_face',
#         'party_popper', 'star-struck', 'face_vomiting', 'pile_of_poo'],
#        dtype='object')]

# %%
data_f = pd.concat([data.reset_index(drop = True), reactions_divided.reset_index(drop = True)], axis = 1)
data_f
# Out:
#                                                 msg_text   views clown_face  \
# 0      😂 Користувачі соцмереж в очікуванні звернення ...  205495   0.042216
# 1      🤬 Російські загарбники продовжують "мобілізаці...  203217   0.011671
# 2      ❗️Місцеві канали повідомляють про звуки вибухі...  205310   0.003957
# 3      ❗️Окупанти б’ють ракетами по дамбі на Харківщи...  210989          0
# 4      ‼️ Українським громадянам влада рекомендує не ...  215432   0.003946
# ...                                                  ...     ...        ...
# 10136  У п'ятницю, 1 липня, російські окупанти випуст...  198618          0
# 10137  ЮНЕСКО остаточно внесла українську національну...  206802          0
# 10138  Президент США Джо Байден повідомив про новий п...  206527          0
# 10139  В Україні стартував сезон малини. Проте аромат...  212290          0
# 10140  У ЗСУ розповіли про джерела, з яких дізнаються...  218062          0
#
#       thumbs_up thumbs_down red_heart      fire smiling_face_with_hearts  \
# 0      0.525066           0  0.047493  0.025066                  0.01847
# 1      0.111578           0  0.004202  0.009337                 0.003735
# 2       0.03522    0.003166  0.003562         0                 0.007519
# 3      0.042405    0.003742  0.002494  0.002744                        0
# 4      0.870109    0.003288  0.071358  0.003946                 0.000987
# ...         ...         ...       ...       ...                      ...
# 10136  0.064867           0  0.004939  0.002305                        0
# 10137  0.143517     0.00154  0.809499  0.003338                 0.015918
# 10138  0.856524    0.001734  0.095362  0.022107                        0
# 10139  0.182081    0.005202   0.69711  0.005202                 0.012717
# 10140  0.664076           0   0.02332  0.003887                 0.001666
#
#       clapping_hands beaming_face_with_smiling_eyes thinking_face  \
# 0           0.019789                       0.277045       0.01847
# 1           0.001401                              0      0.005135
# 2            0.00277                              0             0
# 3           0.001996                              0      0.002993
# 4           0.020059                       0.011181      0.009865
# ...              ...                            ...           ...
# 10136              0                              0      0.005927
# 10137       0.012837                       0.006932      0.002567
# 10138       0.015605                       0.004768      0.001734
# 10139              0                              0      0.002312
# 10140              0                       0.003331      0.007218
#
#       exploding_head face_screaming_in_fear face_with_symbols_on_mouth  \
# 0                  0                      0                          0
# 1           0.028945               0.004202                   0.819795
# 2           0.004353               0.006332                   0.790661
# 3           0.004739               0.106261                   0.778249
# 4                  0                      0                          0
# ...              ...                    ...                        ...
# 10136              0               0.006915                   0.673691
# 10137              0                      0                          0
# 10138              0                      0                   0.000433
# 10139              0               0.016185                          0
# 10140       0.004442                      0                   0.037202
#
#       crying_face party_popper star-struck face_vomiting pile_of_poo
# 0               0     0.005277           0      0.021108           0
# 1               0            0           0             0           0
# 2        0.130985            0           0             0    0.011476
# 3        0.048391            0           0             0    0.005987
# 4               0            0           0      0.005261           0
# ...           ...          ...         ...           ...         ...
# 10136    0.240698            0           0      0.000659           0
# 10137           0            0           0             0    0.003851
# 10138           0            0           0      0.001734           0
# 10139    0.066474            0           0      0.005202    0.007514
# 10140     0.24764            0           0      0.003887    0.003331
#
# [10141 rows x 19 columns]

# %%
data_f.iloc[empty_reactions_indexes, :]
# Out:
# Empty DataFrame
# Columns: [msg_text, views, clown_face, thumbs_up, thumbs_down, red_heart, fire, smiling_face_with_hearts, clapping_hands, beaming_face_with_smiling_eyes, thinking_face, exploding_head, face_screaming_in_fear, face_with_symbols_on_mouth, crying_face, party_popper, star-struck, face_vomiting, pile_of_poo]
# Index: []

# %%
data_f.drop(axis = 0, index = empty_reactions_indexes, inplace = True)

# %%
data_f.msg_text = data_f.msg_text.astype('string', copy = False)

# %%
data_f.msg_text
# Out:
# 0        😂 Користувачі соцмереж в очікуванні звернення ...
# 1        🤬 Російські загарбники продовжують "мобілізаці...
# 2        ❗️Місцеві канали повідомляють про звуки вибухі...
# 3        ❗️Окупанти б’ють ракетами по дамбі на Харківщи...
# 4        ‼️ Українським громадянам влада рекомендує не ...
#                                ...
# 10136    У п'ятницю, 1 липня, російські окупанти випуст...
# 10137    ЮНЕСКО остаточно внесла українську національну...
# 10138    Президент США Джо Байден повідомив про новий п...
# 10139    В Україні стартував сезон малини. Проте аромат...
# 10140    У ЗСУ розповіли про джерела, з яких дізнаються...
# Name: msg_text, Length: 10141, dtype: string

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def preprocess_text(text):
  import re
  import string

  new_text = emoji.replace_emoji(text, replace = '')
  new_text = new_text.replace('\n', '')
  new_text = new_text.lower()
  new_text = re.sub(r'http\S+', '', new_text)

  # deleting all punctuation
  mappingtbl = new_text.maketrans({punct: ' ' for punct in string.punctuation + '–—«»№₤€'})
  new_text = new_text.translate(mappingtbl)
  
  # removing multiple spaces
  new_text = ' '.join(new_text.split())
  return new_text

# %%
s = data_f.msg_text.iloc[-1]
print(preprocess_text(s))
s
# Out:
# у зсу розповіли про джерела з яких дізнаються про ракетну небезпеку і оголошують повітряну тривогуречник повітряних сил україни юрій ігнат наголосив що повітряні сили не мають достатньо засобів для ефективного знищення ворожих цілей детальніше ар
# 'У ЗСУ розповіли про джерела, з яких дізнаються про ракетну небезпеку і оголошують повітряну тривогу\n\nРечник Повітряних Сил України Юрій Ігнат наголосив, що Повітряні сили не мають достатньо засобів для ефективного знищення ворожих цілей.\n\nДетальніше➡️https://bit.ly/3Aoo0Wm\nФото АР'

# %%
data_f.msg_text = data_f.msg_text.apply(preprocess_text)

# %%
data_f
# Out:
#                                                 msg_text   views clown_face  \
# 0      користувачі соцмереж в очікуванні звернення ро...  205495   0.042216
# 1      російські загарбники продовжують мобілізацію н...  203217   0.011671
# 2      місцеві канали повідомляють про звуки вибухів ...  205310   0.003957
# 3      окупанти б’ють ракетами по дамбі на харківщині...  210989          0
# 4      українським громадянам влада рекомендує не від...  215432   0.003946
# ...                                                  ...     ...        ...
# 10136  у п ятницю 1 липня російські окупанти випустил...  198618          0
# 10137  юнеско остаточно внесла українську національну...  206802          0
# 10138  президент сша джо байден повідомив про новий п...  206527          0
# 10139  в україні стартував сезон малини проте ароматн...  212290          0
# 10140  у зсу розповіли про джерела з яких дізнаються ...  218062          0
#
#       thumbs_up thumbs_down red_heart      fire smiling_face_with_hearts  \
# 0      0.525066           0  0.047493  0.025066                  0.01847
# 1      0.111578           0  0.004202  0.009337                 0.003735
# 2       0.03522    0.003166  0.003562         0                 0.007519
# 3      0.042405    0.003742  0.002494  0.002744                        0
# 4      0.870109    0.003288  0.071358  0.003946                 0.000987
# ...         ...         ...       ...       ...                      ...
# 10136  0.064867           0  0.004939  0.002305                        0
# 10137  0.143517     0.00154  0.809499  0.003338                 0.015918
# 10138  0.856524    0.001734  0.095362  0.022107                        0
# 10139  0.182081    0.005202   0.69711  0.005202                 0.012717
# 10140  0.664076           0   0.02332  0.003887                 0.001666
#
#       clapping_hands beaming_face_with_smiling_eyes thinking_face  \
# 0           0.019789                       0.277045       0.01847
# 1           0.001401                              0      0.005135
# 2            0.00277                              0             0
# 3           0.001996                              0      0.002993
# 4           0.020059                       0.011181      0.009865
# ...              ...                            ...           ...
# 10136              0                              0      0.005927
# 10137       0.012837                       0.006932      0.002567
# 10138       0.015605                       0.004768      0.001734
# 10139              0                              0      0.002312
# 10140              0                       0.003331      0.007218
#
#       exploding_head face_screaming_in_fear face_with_symbols_on_mouth  \
# 0                  0                      0                          0
# 1           0.028945               0.004202                   0.819795
# 2           0.004353               0.006332                   0.790661
# 3           0.004739               0.106261                   0.778249
# 4                  0                      0                          0
# ...              ...                    ...                        ...
# 10136              0               0.006915                   0.673691
# 10137              0                      0                          0
# 10138              0                      0                   0.000433
# 10139              0               0.016185                          0
# 10140       0.004442                      0                   0.037202
#
#       crying_face party_popper star-struck face_vomiting pile_of_poo
# 0               0     0.005277           0      0.021108           0
# 1               0            0           0             0           0
# 2        0.130985            0           0             0    0.011476
# 3        0.048391            0           0             0    0.005987
# 4               0            0           0      0.005261           0
# ...           ...          ...         ...           ...         ...
# 10136    0.240698            0           0      0.000659           0
# 10137           0            0           0             0    0.003851
# 10138           0            0           0      0.001734           0
# 10139    0.066474            0           0      0.005202    0.007514
# 10140     0.24764            0           0      0.003887    0.003331
#
# [10141 rows x 19 columns]

# %%
pd.set_option('display.max_colwidth', None)
data_f.msg_text
# Out:
# 0                                                                                                                                                                                                                       користувачі соцмереж в очікуванні звернення російського диктатора почали висувати власні версії того чому виступ путіна затримується та чому був скасований тсн uа зібрав низку дописів та мемів з мережі на тему виступу очільника кремля
# 1                                                                                                                                                                                                         російські загарбники продовжують мобілізацію на окупованих територіях україни влаштовуючи облави окрім того відповідає дійсності інформація про заборону виїзду з окупованого криму на сьогодні залишити крим без дозволу військового комісара неможливо
# 2                                                                                                                                                                                                                                                                                                                                           місцеві канали повідомляють про звуки вибухів у запоріжжі повітряна тривога триває у запорізькій та донецькій областях
# 3                                                                                                                                             окупанти б’ють ракетами по дамбі на харківщині є загроза підтопленняросійські війська протягом останньої доби кілька разів атакували і продовжують обстрілювати дамбу печенізького водосховища у харківській області за оголошення тривоги місцевим жителям необхідно взяти речі першої необхідності та евакуюватися
# 4                                                                                                                                                             українським громадянам влада рекомендує не відвідувати псевдореферендуми які хоче організувати росія проведення таких референдумів нічого не означатиме для україни а от росію очікує посилення санкцій про це сказала міністерка з питань реінтеграції тимчасово окупованих територій ірина верещук
#                                                                                                                                                                                                                                    ...
# 10136                                                                                                                                                                                                              у п ятницю 1 липня російські окупанти випустили понад 270 мін ракет та снарядів різного калібру по території сумщини постраждала 64 річна жінка яка працювала на городі коли почався обстріл її поранило уламком російського снаряду детальніше
# 10137    юнеско остаточно внесла українську національну страву до списку нематеріальної культурної спадщини що потребує термінової охорони через російське вторгнення процедуру визнання улюбленого у світі борщу пришвидшили до цього урядова команда та ентузіасти йшли три роки і виборювали цей статус для унікальної страви як росіяни намагалися вкрасти і цю українську спадщину а українці розривали штучне поєднання москви і борщу дивіться у сюжеті тсн
# 10138                                                                                                                                                                                                                                 президент сша джо байден повідомив про новий пакет підтримки для україни який містить потужні системи nasams пересувні зенітні ракетні комплекси президент зеленський подякував очільнику білого дому за допомогу детальніше
# 10139                                                                                                                                                                                                 в україні стартував сезон малини проте ароматну літню ягоду треба ще пошукати по базарних ятках адже зараз її поки що мало а ціни космічні як вплинула війна на малиновий бізнес українських фермерів і коли зможемо поласувати ягодою без втрат для гаманця
# 10140                                                                                                                                                                                                       у зсу розповіли про джерела з яких дізнаються про ракетну небезпеку і оголошують повітряну тривогуречник повітряних сил україни юрій ігнат наголосив що повітряні сили не мають достатньо засобів для ефективного знищення ворожих цілей детальніше ар
# Name: msg_text, Length: 10141, dtype: object

# %%
data_f.drop(columns = 'views', inplace = True)

# %%
data_f.drop(data_f[data_f.msg_text == ''].index, inplace = True)

# %%
data_f.reset_index(drop = True, inplace = True)

# %%
data_f.to_csv('/content/drive/My Drive/reaction_prediction/tsn_reactions_dataset_from_2_jul.csv')

# %%
# !ls /content/drive/My\ Drive/reaction_prediction
# Out:
# clear_dataset_from_2_jul.json  tsn_reactions_dataset_from_2_jul.csv
# clear_dataset.json	       tsn_reactions_dataset.gsheet
# tsn_reactions_dataset.csv
